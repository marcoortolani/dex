# %%
# !python --version
# Out:
# Python 3.8.10

# %%
import sys; sys.executable
# Out:
# '/opt/homebrew/Caskroom/miniforge/base/bin/python'

# %%
# !jupyter-troubleshoot
# Out:
# $PATH:
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/bin
# 	/Users/marco/.jenv/shims
# 	/Users/marco/.jenv/bin
# 	/opt/homebrew/Caskroom/miniforge/base/condabin
# 	/opt/homebrew/bin
# 	/opt/homebrew/sbin
# 	/usr/local/bin
# 	/usr/bin
# 	/bin
# 	/usr/sbin
# 	/sbin
# 	/Library/TeX/texbin
# 	/opt/X11/bin
# 	/Library/Apple/usr/bin
#
# sys.path:
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/bin
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python38.zip
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python3.8
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python3.8/lib-dynload
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python3.8/site-packages
#
# sys.executable:
# 	/opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/bin/python
#
# sys.version:
# 	3.8.10 | packaged by conda-forge | (default, May 11 2021, 06:27:18)
# 	[Clang 11.1.0 ]
#
# platform.platform():
# ...

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/9_/9p2hyb0j4mg509l8lhprk_880000gn/T/ipykernel_12953/2172125874.py in <module>
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'
